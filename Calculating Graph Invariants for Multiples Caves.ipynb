# %%
from pathlib import Path
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import yaml
import numpy as np

# %%
REPO = Path.home() / "Documents" / "GitHub" / "KNdata-public"
DATA_ROOT = REPO / "caves_fulldatasets"
summary_file = DATA_ROOT / "caves_properties_summary.csv"

print("Summary file:", summary_file)
print("Exists?", summary_file.exists())

table_caves = pd.read_csv(
    summary_file,
    sep=";",
    index_col=1,
    dtype={"id_subset": str, "id_dataset": str},
)

print(type(table_caves))
print(table_caves.head())
print(table_caves.columns)
# Out:
# Summary file: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\caves_properties_summary.csv
# Exists? True
# <class 'pandas.core.frame.DataFrame'>
#               id_dataset id_subset status         type_of_correction  \
# short_name
# GouffreDejaVu        001       000  clean              no correction
# Migovec              002       000  clean          manual correction
# Criou                003       000  clean          manual correction
# Matienzo             004       000  clean  semi-automatic correction
# Sakany               005       000  clean          manual correction
#
#               last_processing_date  total_length  total_depth  \
# short_name
# GouffreDejaVu          11 Nov 2025           150        32.16
# Migovec                11 Nov 2025         46317       968.62
# Criou                  11 Nov 2025         31680      1669.43
# Matienzo               11 Nov 2025        378972       843.00
# Sakany                 11 Nov 2025          6846       140.71
#
#                percentage_csdim  number_connected_components  number_nodes  \
# short_name
# GouffreDejaVu               100                            1            33
# Migovec                      13                            1          7163
# Criou                        28                           20          5085
# Matienzo                      1                          583         55607
# Sakany                       94                           12          1776
#
#                ...   aspl    cpd  correlation_vertex_degree   country  \
# short_name     ...
# GouffreDejaVu  ...   1.50  1.000                     -1.000     Chile
# Migovec        ...  35.94  0.555                     -0.304  Slovenia
# Criou          ...  23.46  0.290                     -0.267    France
# Matienzo       ...  18.34  0.007                     -0.297     Spain
# Sakany         ...  11.88  0.195                     -0.136    France
#
#                latitude  longitude  altitude          license  \
# short_name
# GouffreDejaVu -50.08610  -75.15940       280  CC BY-NC-SA 4.0
# Migovec        46.25198   13.76394      1854  CC BY-NC-SA 4.0
# Criou          46.08890    6.77050      1880  CC BY-NC-SA 4.0
# Matienzo       43.30670   -3.63150       293  CC BY-NC-SA 4.0
# Sakany         42.83590    1.59590       138  CC BY-NC-SA 4.0
#
#                                                         citation  thanks
# short_name
# GouffreDejaVu  Centre Terre. (2024). Survey Data for the Ulti...     NaN
# Migovec        ICCC, & JSDPT. (2024). Survey Data for the Tol...     NaN
# Criou          Robert, X., & Collectif Criou. (2023). Base de...     NaN
# Matienzo       Matienzo Caves Project Expeditions. (2025). Ma...     NaN
# Sakany         Groupe de Recherches et d’Activités Spéléologi...     NaN
#
# [5 rows x 30 columns]
# Index(['id_dataset', 'id_subset', 'status', 'type_of_correction',
#        'last_processing_date', 'total_length', 'total_depth',
#        'percentage_csdim', 'number_connected_components', 'number_nodes',
#        'number_edges', 'mean_degree', 'min_degree', 'max_degree', 'cv_degree',
#        'number_cycles', 'mean_length', 'cv_length', 'length_entropy',
#        'orientation_3d_entropy', 'aspl', 'cpd', 'correlation_vertex_degree',
#        'country', 'latitude', 'longitude', 'altitude', 'license', 'citation',
#        'thanks'],
#       dtype='object')

# %%
def spectral_invariants(G, tol=1e-9):
    if G.number_of_nodes() == 0:
        raise ValueError("Graph is empty.")

    if not nx.is_connected(G):
        largest_cc = max(nx.connected_components(G), key=len)
        G = G.subgraph(largest_cc).copy()
        print("Graph was disconnected; using largest connected component.")

    nodes = list(G.nodes())
    n = len(nodes)
    m = G.number_of_edges()

    A = nx.to_numpy_array(G, nodelist=nodes, dtype=float)
    L = nx.laplacian_matrix(G, nodelist=nodes).toarray().astype(float)
    degrees = A.sum(axis=1)
    D = np.diag(degrees)
    Q = D + A

    D_inv_sqrt = np.zeros((n, n), dtype=float)
    for i in range(n):
        if degrees[i] > tol:
            D_inv_sqrt[i, i] = 1.0 / np.sqrt(degrees[i])
    Lnorm = np.eye(n) - D_inv_sqrt @ A @ D_inv_sqrt

    adj_eigs = np.sort(np.linalg.eigvalsh(A))[::-1]
    lap_eigs = np.sort(np.linalg.eigvalsh(L))
    q_eigs = np.sort(np.linalg.eigvalsh(Q))
    norm_lap_eigs = np.sort(np.linalg.eigvalsh(Lnorm))

    spectral_radius = float(np.max(np.abs(adj_eigs)))
    algebraic_connectivity = float(lap_eigs[1]) if n >= 2 else 0.0
    normalized_algebraic_connectivity = float(norm_lap_eigs[1]) if n >= 2 else 0.0
    graph_energy = float(np.sum(np.abs(adj_eigs)))
    avg_degree = 2 * m / n
    laplacian_energy = float(np.sum(np.abs(lap_eigs - avg_degree)))
    estrada_index = float(np.sum(np.exp(adj_eigs)))

    positive_lap_eigs = lap_eigs[lap_eigs > tol]
    kirchhoff_index = float(n * np.sum(1.0 / positive_lap_eigs)) if len(positive_lap_eigs) == n - 1 else np.nan

    L_minor = L[1:, 1:]
    num_spanning_trees = round(np.linalg.det(L_minor))

    pos_inertia = int(np.sum(adj_eigs > tol))
    zero_inertia = int(np.sum(np.abs(adj_eigs) <= tol))
    neg_inertia = int(np.sum(adj_eigs < -tol))

    return {
        "n": n,
        "m": m,
        "spectral_radius": spectral_radius,
        "algebraic_connectivity": algebraic_connectivity,
        "normalized_algebraic_connectivity": normalized_algebraic_connectivity,
        "graph_energy": graph_energy,
        "laplacian_energy": laplacian_energy,
        "estrada_index": estrada_index,
        "kirchhoff_index": kirchhoff_index,
        "num_spanning_trees": num_spanning_trees,
        "adjacency_inertia": (pos_inertia, zero_inertia, neg_inertia),
        "adjacency_eigenvalues": adj_eigs,
        "laplacian_eigenvalues": lap_eigs,
        "signless_laplacian_eigenvalues": q_eigs,
        "normalized_laplacian_eigenvalues": norm_lap_eigs,
    }

# %%
test_cave = table_caves.index[0]
print("Testing cave:", test_cave)

G = load_karst_graph(test_cave)
print(G.number_of_nodes(), G.number_of_edges())

inv = spectral_invariants(G)
print(inv["n"], inv["m"], inv["kirchhoff_index"])
# Out:
# Testing cave: GouffreDejaVu
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\001_GouffreDejaVu_000\001_GouffreDejaVu_000.yaml
# 40 32
# Graph was disconnected; using largest connected component.
# 33 32 5776.000000000034

# %%
import yaml

class KarstLoader(yaml.FullLoader):
    pass

def construct_python_tuple(loader, node):
    return tuple(loader.construct_sequence(node))

KarstLoader.add_constructor(
    "tag:yaml.org,2002:python/tuple",
    construct_python_tuple
)

print("KarstLoader is ready")
# Out:
# KarstLoader is ready

# %%
def load_karst_graph(cavename):
    id_dataset = table_caves.loc[cavename, "id_dataset"]
    id_subset = table_caves.loc[cavename, "id_subset"]

    yaml_folder = DATA_ROOT / "data" / f"{id_dataset}_{cavename}_{id_subset}"
    path_to_yaml = yaml_folder / f"{id_dataset}_{cavename}_{id_subset}.yaml"

    print("Trying:", path_to_yaml)

    if not path_to_yaml.exists():
        print(f"Missing YAML for {cavename}")
        return None

    with open(path_to_yaml, "r", encoding="utf-8") as f:
        data = yaml.load(f, Loader=KarstLoader)

    G = nx.Graph()

    node_attrs = data.get("node_attributes", {})
    for node, attrs in node_attrs.items():
        if isinstance(attrs, dict):
            clean_attrs = {str(k): v for k, v in attrs.items()}
            G.add_node(node, **clean_attrs)
        else:
            G.add_node(node)

    edges = data.get("edges", [])
    for e in edges:
        if isinstance(e, dict):
            u = e.get("u") or e.get("source")
            v = e.get("v") or e.get("target")
            clean_attrs = {
                str(k): val for k, val in e.items()
                if k not in ["u", "v", "source", "target"]
            }
            if u is not None and v is not None:
                G.add_edge(u, v, **clean_attrs)
        elif isinstance(e, (list, tuple)) and len(e) >= 2:
            G.add_edge(e[0], e[1])

    return G

# %%
G = load_karst_graph("Migovec")
print(G.number_of_nodes(), G.number_of_edges())
# Out:
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\002_Migovec_000\002_Migovec_000.yaml
# 7170 7206

# %%
results = []

for cavename in table_caves.index:
    try:
        print(f"Processing: {cavename}")

        G = load_karst_graph(cavename)

        if G is None or G.number_of_nodes() == 0:
            print("Skipping empty graph.")
            continue

        inv = spectral_invariants(G)

        row = {
            "cavename": cavename,
            "n": inv["n"],
            "m": inv["m"],
            "spectral_radius": inv["spectral_radius"],
            "algebraic_connectivity": inv["algebraic_connectivity"],
            "normalized_algebraic_connectivity": inv["normalized_algebraic_connectivity"],
            "graph_energy": inv["graph_energy"],
            "laplacian_energy": inv["laplacian_energy"],
            "estrada_index": inv["estrada_index"],
            "kirchhoff_index": inv["kirchhoff_index"],
            "num_spanning_trees": inv["num_spanning_trees"],
        }

        results.append(row)

    except Exception as e:
        print(f"Skipping {cavename}: {e}")
# Out:
# Processing: GouffreDejaVu
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\001_GouffreDejaVu_000\001_GouffreDejaVu_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Migovec
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\002_Migovec_000\002_Migovec_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Criou
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\003_Criou_000\003_Criou_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Matienzo
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\004_Matienzo_000\004_Matienzo_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Sakany
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\005_Sakany_000\005_Sakany_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: ReveEveille
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\006_ReveEveille_000\006_ReveEveille_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Tsanfleuron
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\007_Tsanfleuron_000\007_Tsanfleuron_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: UltimaPatagonia
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\008_UltimaPatagonia_000\008_UltimaPatagonia_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Folly
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\009_Folly_000\009_Folly_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: PlaninaPoljana
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\010_PlaninaPoljana_000\010_PlaninaPoljana_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: BreznoNaToscu
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\011_BreznoNaToscu_000\011_BreznoNaToscu_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: PokljuskegaGrebena
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\012_PokljuskegaGrebena_000\012_PokljuskegaGrebena_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: BurringtonCombe
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\013_BurringtonCombe_000\013_BurringtonCombe_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: CheddarCatchment
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\014_CheddarCatchment_000\014_CheddarCatchment_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: CountyClare
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\015_CountyClare_000\015_CountyClare_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: CountyMayo
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\016_CountyMayo_000\016_CountyMayo_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: LittleNeathRiver
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\017_LittleNeathRiver_000\017_LittleNeathRiver_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Lathkill
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\018_Lathkill_000\018_Lathkill_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Loser
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\019_Loser_000\019_Loser_000.yaml
# Graph was disconnected; using largest connected component.
# C:\Users\roz31\anaconda3\Lib\site-packages\numpy\linalg\_linalg.py:2431: RuntimeWarning: overflow encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# Skipping Loser: cannot convert float infinity to integer
# Processing: Vanoise
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\020_Vanoise_000\020_Vanoise_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Glacier
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\021_Glacier_000\021_Glacier_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: CombeBryon
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\022_CombeBryon_000\022_CombeBryon_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Charbonniere
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\023_Charbonniere_000\023_Charbonniere_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Lajoux
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\024_Lajoux_000\024_Lajoux_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: PuitsWilly
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\026_PuitsWilly_000\026_PuitsWilly_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: CreuxDEntier
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\027_CreuxDEntier_000\027_CreuxDEntier_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: NarinesBoeuf
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\028_NarinesBoeuf_000\028_NarinesBoeuf_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: RougeEau
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\029_RougeEau_000\029_RougeEau_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: DYO
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\031_DYO_000\031_DYO_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: FermanagAndCavan
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\032_FermanagAndCavan_000\032_FermanagAndCavan_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: WestKingsdale
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\033_WestKingsdale_000\033_WestKingsdale_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: EastKingsdale
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\035_EastKingsdale_000\035_EastKingsdale_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: ShkembejtJames
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\036_ShkembejtJames_000\036_ShkembejtJames_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: FountainsFell
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\037_FountainsFell_000\037_FountainsFell_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Ingleborough
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\038_Ingleborough_000\038_Ingleborough_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: DunaldMill
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\039_DunaldMill_000\039_DunaldMill_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Nidderdale
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\040_Nidderdale_000\040_Nidderdale_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: ThreeCounties
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\041_ThreeCounties_000\041_ThreeCounties_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: DowProv
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\042_DowProv_000\042_DowProv_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: HaggBeck
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\043_HaggBeck_000\043_HaggBeck_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Seefeldhoele
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\047_Seefeldhoele_000\047_Seefeldhoele_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Banquier
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\048_Banquier_000\048_Banquier_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Cochon
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\049_Cochon_000\049_Cochon_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Andara
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\050_Andara_000\050_Andara_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Koytendag
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\054_Koytendag_000\054_Koytendag_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Tatra
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\055_Tatra_000\055_Tatra_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: ClydachGorge
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\056_ClydachGorge_000\056_ClydachGorge_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Cavernicole
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\058_Cavernicole_000\058_Cavernicole_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: FontaineNoire
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\059_FontaineNoire_000\059_FontaineNoire_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: ClotAspres
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\060_ClotAspres_000\060_ClotAspres_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Moucherotte
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\061_Moucherotte_000\061_Moucherotte_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Sornin
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\062_Sornin_000\062_Sornin_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Perthuis
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\063_Perthuis_000\063_Perthuis_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Blau
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\066_Blau_000\066_Blau_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Bailleurs
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\067_Bailleurs_000\067_Bailleurs_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Mandra
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\068_Mandra_000\068_Mandra_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Argent
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\069_Argent_000\069_Argent_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Cheminee
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\070_Cheminee_000\070_Cheminee_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Carcabon
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\071_Carcabon_000\071_Carcabon_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Serreno
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\073_Serreno_000\073_Serreno_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Yeux
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\074_Yeux_000\074_Yeux_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: TorcaAitken
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\075_TorcaAitken_000\075_TorcaAitken_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: CuevaCarrera
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\076_CuevaCarrera_000\076_CuevaCarrera_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Pasillo
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\077_Pasillo_000\077_Pasillo_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: CuevaPollita
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\079_CuevaPollita_000\079_CuevaPollita_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Lastrias
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\080_Lastrias_000\080_Lastrias_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: CuevaTonia
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\082_CuevaTonia_000\082_CuevaTonia_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Cubillo
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\083_Cubillo_000\083_Cubillo_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: CuevaHelguera
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\084_CuevaHelguera_000\084_CuevaHelguera_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Requiem
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\085_Requiem_000\085_Requiem_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: CoumeBere
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\087_CoumeBere_000\087_CoumeBere_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: PerteYerse
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\088_PerteYerse_000\088_PerteYerse_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Queou
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\089_Queou_000\089_Queou_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Crolles
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\090_Crolles_000\090_Crolles_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Som
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\091_Som_000\091_Som_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Flaine
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\092_Flaine_000\092_Flaine_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Larra
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\093_Larra_000\093_Larra_000.yaml
# Graph was disconnected; using largest connected component.
# Processing: Kelmend
# Trying: C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\095_Kelmend_000\095_Kelmend_000.yaml
# Graph was disconnected; using largest connected component.

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Saved karst_spectral_summary.csv

# %%
df_results = pd.DataFrame(results)
print(df_results.head())
print("Number of successful caves:", len(df_results))
# Out:
#         cavename     n     m  spectral_radius  algebraic_connectivity  \
# 0  GouffreDejaVu    33    32         2.084868                0.009304
# 1        Migovec  7163  7206         2.712534                0.000002
# 2          Criou  3721  3741         2.539595                0.000003
# 3       Matienzo  6058  6128         2.944484                0.000003
# 4         Sakany  1426  1467         2.591274                0.000254
#
#    normalized_algebraic_connectivity  graph_energy  laplacian_energy  \
# 0                       4.939860e-03     41.181433         42.315047
# 1                       9.031247e-07   9047.131678       9359.579629
# 2                       1.535872e-06   4699.140794       4855.234588
# 3                       1.489627e-06   7548.951682       8165.693375
# 4                       1.238592e-04   1808.154063       1911.334478
#
#    estrada_index  kirchhoff_index  \
# 0      73.966387     5.776000e+03
# 1   16531.739882     8.084940e+09
# 2    8573.788561     2.316173e+09
# 3   14169.059208     4.388694e+09
# 4    3371.417160     3.078307e+07
#
#                                   num_spanning_trees
# 0                                                  1
# 1  6552299513630932481020990079976216966114481562...
# 2                      20712341509537694792944713728
# 3  8982596641536942067564900390445483866598525406...
# 4  1560983054396353018812039519790628118139953509...
# Number of successful caves: 77

# %%
df_results.to_csv("karst_spectral_summary.csv", index=False)
print("Saved successfully.")
# Out:
# Saved successfully.

# %%
from pathlib import Path
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import yaml
import numpy as np

# --------------------------------------------------
# Spectral invariants for a Karst graph
# --------------------------------------------------
def spectral_invariants(G, tol=1e-9):
    if G.number_of_nodes() == 0:
        raise ValueError("Graph is empty.")

    # keep only largest connected component if needed
    if not nx.is_connected(G):
        largest_cc = max(nx.connected_components(G), key=len)
        G = G.subgraph(largest_cc).copy()
        print("\nGraph was disconnected; invariants computed on largest connected component.")

    nodes = list(G.nodes())
    n = len(nodes)
    m = G.number_of_edges()

    A = nx.to_numpy_array(G, nodelist=nodes, dtype=float)
    L = nx.laplacian_matrix(G, nodelist=nodes).toarray().astype(float)
    degrees = A.sum(axis=1)
    D = np.diag(degrees)
    Q = D + A

    # normalized Laplacian
    D_inv_sqrt = np.zeros((n, n), dtype=float)
    for i in range(n):
        if degrees[i] > tol:
            D_inv_sqrt[i, i] = 1.0 / np.sqrt(degrees[i])
    Lnorm = np.eye(n) - D_inv_sqrt @ A @ D_inv_sqrt

    # eigenvalues
    adj_eigs = np.sort(np.linalg.eigvalsh(A))[::-1]
    lap_eigs = np.sort(np.linalg.eigvalsh(L))
    q_eigs = np.sort(np.linalg.eigvalsh(Q))
    norm_lap_eigs = np.sort(np.linalg.eigvalsh(Lnorm))

    spectral_radius = float(np.max(np.abs(adj_eigs)))
    algebraic_connectivity = float(lap_eigs[1]) if n >= 2 else 0.0
    normalized_algebraic_connectivity = float(norm_lap_eigs[1]) if n >= 2 else 0.0
    graph_energy = float(np.sum(np.abs(adj_eigs)))
    avg_degree = 2 * m / n
    laplacian_energy = float(np.sum(np.abs(lap_eigs - avg_degree)))
    estrada_index = float(np.sum(np.exp(adj_eigs)))

    positive_lap_eigs = lap_eigs[lap_eigs > tol]
    kirchhoff_index = float(n * np.sum(1.0 / positive_lap_eigs)) if len(positive_lap_eigs) == n - 1 else np.nan

    # spanning trees via Matrix-Tree theorem
    L_minor = L[1:, 1:]
    num_spanning_trees = round(np.linalg.det(L_minor))

    pos_inertia = int(np.sum(adj_eigs > tol))
    zero_inertia = int(np.sum(np.abs(adj_eigs) <= tol))
    neg_inertia = int(np.sum(adj_eigs < -tol))

    return {
        "n": n,
        "m": m,
        "spectral_radius": spectral_radius,
        "algebraic_connectivity": algebraic_connectivity,
        "normalized_algebraic_connectivity": normalized_algebraic_connectivity,
        "graph_energy": graph_energy,
        "laplacian_energy": laplacian_energy,
        "estrada_index": estrada_index,
        "kirchhoff_index": kirchhoff_index,
        "num_spanning_trees": num_spanning_trees,
        "adjacency_inertia": (pos_inertia, zero_inertia, neg_inertia),
        "adjacency_eigenvalues": adj_eigs,
        "laplacian_eigenvalues": lap_eigs,
        "signless_laplacian_eigenvalues": q_eigs,
        "normalized_laplacian_eigenvalues": norm_lap_eigs,
    }








# --------------------------------------------------
# Loop over all caves
# --------------------------------------------------

results = []

for cavename in table_caves.index:

    try:
        print(f"\nProcessing: {cavename}")

        id_dataset = table_caves.loc[cavename, "id_dataset"]
        id_subset = table_caves.loc[cavename, "id_subset"]

        yaml_folder = DATA_ROOT / "data" / f"{id_dataset}_{cavename}_{id_subset}"
        path_to_yaml = yaml_folder / f"{id_dataset}_{cavename}_{id_subset}.yaml"

        if not path_to_yaml.exists():
            print("YAML not found, skipping...")
            continue

        # --- Load YAML ---
        with open(path_to_yaml, "r", encoding="utf-8") as f:
            data = yaml.safe_load(f)

        # --- Build graph ---
        G = nx.Graph()

        # Nodes
        node_attrs = data.get("node_attributes", {})
        for node, attrs in node_attrs.items():
            if isinstance(attrs, dict):
                G.add_node(node, **attrs)
            else:
                G.add_node(node)

        # Edges
        edges = data.get("edges", [])
        for e in edges:
            if isinstance(e, dict):
                u = e.get("u") or e.get("source")
                v = e.get("v") or e.get("target")
                if u is not None and v is not None:
                    G.add_edge(u, v)
            elif isinstance(e, (list, tuple)) and len(e) >= 2:
                G.add_edge(e[0], e[1])

        if G.number_of_nodes() == 0:
            print("Empty graph, skipping...")
            continue

        # --- Compute invariants ---
        inv = spectral_invariants(G)

        # --- Store results ---
        row = {
            "cavename": cavename,
            "n": inv["n"],
            "m": inv["m"],
            "spectral_radius": inv["spectral_radius"],
            "algebraic_connectivity": inv["algebraic_connectivity"],
            "normalized_algebraic_connectivity": inv["normalized_algebraic_connectivity"],
            "graph_energy": inv["graph_energy"],
            "laplacian_energy": inv["laplacian_energy"],
            "estrada_index": inv["estrada_index"],
            "kirchhoff_index": inv["kirchhoff_index"],
            "num_spanning_trees": inv["num_spanning_trees"],
        }

        results.append(row)

    except Exception as e:
        print(f"Error for {cavename}: {e}")
        continue


# --------------------------------------------------
# Convert to DataFrame
# --------------------------------------------------
df_results = pd.DataFrame(results)

print("\nFinal table:")
print(df_results.head())


df_results.to_csv("karst_spectral_summary.csv", index=False)


print(df_results.head())
print(df_results.describe())
print(df_results.corr(numeric_only=True))

plt.figure(figsize=(8,6))
plt.scatter(df_results["n"], df_results["kirchhoff_index"])
plt.xlabel("Number of nodes (n)")
plt.ylabel("Kirchhoff index")
plt.title("Kirchhoff index vs number of nodes")
plt.show()




    

# --------------------------------------------------
# Paths
# --------------------------------------------------
REPO = Path.home() / "Documents" / "GitHub" / "KNdata-public"
DATA_ROOT = REPO / "caves_fulldatasets"
summary_file = DATA_ROOT / "caves_properties_summary.csv"

# --------------------------------------------------
# Read summary
# --------------------------------------------------
table_caves = pd.read_csv(
    summary_file,
    sep=";",
    index_col=1,
    dtype={"id_subset": str, "id_dataset": str},
)

# --------------------------------------------------
# Select cave
# --------------------------------------------------
cavename = "GouffreDejaVu"
id_dataset = table_caves.loc[cavename, "id_dataset"]
id_subset = table_caves.loc[cavename, "id_subset"]

yaml_folder = DATA_ROOT / "data" / f"{id_dataset}_{cavename}_{id_subset}"
path_to_yaml = yaml_folder / f"{id_dataset}_{cavename}_{id_subset}.yaml"

print("YAML path:", path_to_yaml)
print("Exists?", path_to_yaml.exists())

# --------------------------------------------------
# Load YAML
# --------------------------------------------------
with open(path_to_yaml, "r", encoding="utf-8") as f:
    data = yaml.safe_load(f)

print("\nTop-level YAML keys:", list(data.keys()))

# --------------------------------------------------
# Build graph
# --------------------------------------------------
G = nx.Graph()

# --- Nodes ---
node_attrs = data.get("node_attributes", {})
for node, attrs in node_attrs.items():
    if isinstance(attrs, dict):
        clean_attrs = {str(k): v for k, v in attrs.items()}
        G.add_node(node, **clean_attrs)
    else:
        G.add_node(node)

# --- Edges ---
edges = data.get("edges", [])
for e in edges:
    if isinstance(e, dict):
        u = e.get("u") or e.get("source")
        v = e.get("v") or e.get("target")

        clean_attrs = {
            str(k): val for k, val in e.items()
            if k not in ["u", "v", "source", "target"]
        }

        if u is not None and v is not None:
            G.add_edge(u, v, **clean_attrs)

    elif isinstance(e, (list, tuple)) and len(e) >= 2:
        G.add_edge(e[0], e[1])

# --- Metadata ---
meta = data.get("metadata", {})
for k, v in meta.items():
    G.graph[str(k)] = v

# --------------------------------------------------
# Print summary
# --------------------------------------------------
print("\nGraph summary:")
print("number of nodes =", G.number_of_nodes())
print("number of edges =", G.number_of_edges())

print("\nMetadata:")
for k, v in G.graph.items():
    print(k, "=", v)

# --------------------------------------------------
# Compute spectral invariants
# --------------------------------------------------
inv = spectral_invariants(G)

print("\nSpectral invariants:")
for key in [
    "n",
    "m",
    "spectral_radius",
    "algebraic_connectivity",
    "normalized_algebraic_connectivity",
    "graph_energy",
    "laplacian_energy",
    "estrada_index",
    "kirchhoff_index",
    "num_spanning_trees",
    "adjacency_inertia",
]:
    print(f"{key} = {inv[key]}")

print("\nLargest adjacency eigenvalues:")
print(inv["adjacency_eigenvalues"][:10])

print("\nSmallest Laplacian eigenvalues:")
print(inv["laplacian_eigenvalues"][:10])

# --------------------------------------------------
# Plot
# --------------------------------------------------
if G.number_of_nodes() > 0:
    plt.figure(figsize=(8, 6))
    pos = nx.spring_layout(G, seed=1)
    nx.draw(G, pos, node_size=10, with_labels=False)
    plt.title(f"Karst graph: {cavename}")
    plt.show()
else:
    print("\nNo graph was built — send me print(data) if this happens.")
# Out:
# Processing: GouffreDejaVu
# Error for GouffreDejaVu: keywords must be strings
#
# Processing: Migovec
# Error for Migovec: could not determine a constructor for the tag 'tag:yaml.org,2002:python/tuple'
#   in "C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\002_Migovec_000\002_Migovec_000.yaml", line 14475, column 7
#
# Processing: Criou
# Error for Criou: could not determine a constructor for the tag 'tag:yaml.org,2002:python/tuple'
#   in "C:\Users\roz31\Documents\GitHub\KNdata-public\caves_fulldatasets\data\003_Criou_000\003_Criou_000.yaml", line 10247, column 7
#
# Processing: Matienzo
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 111
#     109 # --- Load YAML ---
#     110 with open(path_to_yaml, "r", encoding="utf-8") as f:
# --> 111     data = yaml.safe_load(f)
#     113 # --- Build graph ---
#     114 G = nx.Graph()
#
# File ~\anaconda3\Lib\site-packages\yaml\__init__.py:125, in safe_load(stream)
#     117 def safe_load(stream):
#     118     """
#     119     Parse the first YAML document in a stream
#     120     and produce the corresponding Python object.
#    (...)    123     to be safe for untrusted input.
#     124     """
# --> 125     return load(stream, SafeLoader)
#
# File ~\anaconda3\Lib\site-packages\yaml\__init__.py:81, in load(stream, Loader)
#      79 loader = Loader(stream)
#      80 try:
# ---> 81     return loader.get_single_data()
#      82 finally:
#      83     loader.dispose()
#
# File ~\anaconda3\Lib\site-packages\yaml\constructor.py:49, in BaseConstructor.get_single_data(self)
#      47 def get_single_data(self):
#      48     # Ensure that the stream contains a single document and construct it.
# ---> 49     node = self.get_single_node()
#      50     if node is not None:
#      51         return self.construct_document(node)
#
# File ~\anaconda3\Lib\site-packages\yaml\composer.py:36, in Composer.get_single_node(self)
#      34 document = None
#      35 if not self.check_event(StreamEndEvent):
# ---> 36     document = self.compose_document()
#      38 # Ensure that the stream contains no more documents.
#      39 if not self.check_event(StreamEndEvent):
#
# File ~\anaconda3\Lib\site-packages\yaml\composer.py:55, in Composer.compose_document(self)
#      52 self.get_event()
#      54 # Compose the root node.
# ---> 55 node = self.compose_node(None, None)
#      57 # Drop the DOCUMENT-END event.
#      58 self.get_event()
#
# File ~\anaconda3\Lib\site-packages\yaml\composer.py:84, in Composer.compose_node(self, parent, index)
#      82     node = self.compose_sequence_node(anchor)
#      83 elif self.check_event(MappingStartEvent):
# ---> 84     node = self.compose_mapping_node(anchor)
#      85 self.ascend_resolver()
#      86 return node
#
# File ~\anaconda3\Lib\site-packages\yaml\composer.py:133, in Composer.compose_mapping_node(self, anchor)
#     129 item_key = self.compose_node(node, None)
#     130 #if item_key in node.value:
#     131 #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132 #            "found duplicate key", key_event.start_mark)
# --> 133 item_value = self.compose_node(node, item_key)
#     134 #node.value[item_key] = item_value
#     135 node.value.append((item_key, item_value))
#
# File ~\anaconda3\Lib\site-packages\yaml\composer.py:84, in Composer.compose_node(self, parent, index)
#      82     node = self.compose_sequence_node(anchor)
#      83 elif self.check_event(MappingStartEvent):
# ---> 84     node = self.compose_mapping_node(anchor)
#      85 self.ascend_resolver()
#      86 return node
#
# File ~\anaconda3\Lib\site-packages\yaml\composer.py:133, in Composer.compose_mapping_node(self, anchor)
#     129 item_key = self.compose_node(node, None)
#     130 #if item_key in node.value:
#     131 #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132 #            "found duplicate key", key_event.start_mark)
# --> 133 item_value = self.compose_node(node, item_key)
#     134 #node.value[item_key] = item_value
#     135 node.value.append((item_key, item_value))
#
# File ~\anaconda3\Lib\site-packages\yaml\composer.py:84, in Composer.compose_node(self, parent, index)
#      82     node = self.compose_sequence_node(anchor)
#      83 elif self.check_event(MappingStartEvent):
# ---> 84     node = self.compose_mapping_node(anchor)
#      85 self.ascend_resolver()
#      86 return node
#
# File ~\anaconda3\Lib\site-packages\yaml\composer.py:133, in Composer.compose_mapping_node(self, anchor)
#     129 item_key = self.compose_node(node, None)
#     130 #if item_key in node.value:
#     131 #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132 #            "found duplicate key", key_event.start_mark)
# --> 133 item_value = self.compose_node(node, item_key)
#     134 #node.value[item_key] = item_value
#     135 node.value.append((item_key, item_value))
#
# File ~\anaconda3\Lib\site-packages\yaml\composer.py:64, in Composer.compose_node(self, parent, index)
#      63 def compose_node(self, parent, index):
# ---> 64     if self.check_event(AliasEvent):
#      65         event = self.get_event()
#      66         anchor = event.anchor
#
# File ~\anaconda3\Lib\site-packages\yaml\parser.py:98, in Parser.check_event(self, *choices)
#      96 if self.current_event is None:
#      97     if self.state:
# ---> 98         self.current_event = self.state()
#      99 if self.current_event is not None:
#     100     if not choices:
#
# File ~\anaconda3\Lib\site-packages\yaml\parser.py:449, in Parser.parse_block_mapping_value(self)
#     447 if self.check_token(ValueToken):
#     448     token = self.get_token()
# --> 449     if not self.check_token(KeyToken, ValueToken, BlockEndToken):
#     450         self.states.append(self.parse_block_mapping_key)
#     451         return self.parse_block_node_or_indentless_sequence()
#
# File ~\anaconda3\Lib\site-packages\yaml\scanner.py:116, in Scanner.check_token(self, *choices)
#     113 def check_token(self, *choices):
#     114     # Check if the next token is one of the given types.
#     115     while self.need_more_tokens():
# --> 116         self.fetch_more_tokens()
#     117     if self.tokens:
#     118         if not choices:
#
# File ~\anaconda3\Lib\site-packages\yaml\scanner.py:159, in Scanner.fetch_more_tokens(self)
#     156 def fetch_more_tokens(self):
#     157
#     158     # Eat whitespaces and comments until we reach the next token.
# --> 159     self.scan_to_next_token()
#     161     # Remove obsolete possible simple keys.
#     162     self.stale_possible_simple_keys()
#
# File ~\anaconda3\Lib\site-packages\yaml\scanner.py:776, in Scanner.scan_to_next_token(self)
#     774 found = False
#     775 while not found:
# --> 776     while self.peek() == ' ':
#     777         self.forward()
#     778     if self.peek() == '#':
#
# KeyboardInterrupt:
